# %% [markdown]
# Imports

# %%
#imports for neural network
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchsummary import summary

#imports for vision
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid


#imports for visualizations
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from PIL import Image

# %% [markdown]
# Raw Image

# %%
pistol_path = 'demo_images/pistol_demo.jpg'
no_pistol_path = 'demo_images/no_pistol_demo.jpg'

pistol_image = Image.open(pistol_path)
no_pistol_image = Image.open(no_pistol_path)

plt.subplot(1, 2, 1)
plt.imshow(pistol_image)
plt.title('Raw Concealed Pistol Image')
plt.axis('off')


plt.subplot(1, 2, 2)
plt.imshow(no_pistol_image)
plt.title('Raw No Pistol Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# Preprocessed Image

# %% [markdown]
# Loading Model

# %% [markdown]
# Testing Model On Image

# %% [markdown]
# Output Prediction

# %% [markdown]
# Ideal Bounding Boxes
